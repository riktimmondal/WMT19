# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !ls "/content/gdrive/My Drive"
path="/content/gdrive/My Drive"
# Out:
# '1)Gujarati-English Translation task:.gdoc'   OpenNMT-py-master
#  assignment1.sh				      Resume.gdoc
#  BCSEIII				      Shankha_BCSEII_78
#  BCSEIII1.zip				      SRN.pdf
# 'Classifieds - Invitations.pptx'	     'SRN - Shankha raj Nayek.pdf'
# 'Colab Notebooks'			     'Systems programming'
#  CSessional_2016.pdf			     "test'.ipynb"
#  diffeq.c				      Untitled0.ipynb
#  EN-BN_Word-level.ipynb			      Untitled1.ipynb
#  jordan.c				     'Who we are.pdf'
# 'Mathematics III 2015.pdf'

# %%
cd $path
# Out:
# /content/gdrive/My Drive

# %%
# !git clone https://github.com/OpenNMT/OpenNMT.git
# Out:
# Cloning into 'OpenNMT'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 19245 (delta 2), reused 0 (delta 0), pack-reused 19240
# Receiving objects: 100% (19245/19245), 26.33 MiB | 7.78 MiB/s, done.
# Resolving deltas: 100% (12011/12011), done.
# Checking out files: 100% (284/284), done.

# %%
ls
# Out:
# '1)Gujarati-English Translation task:.gdoc'   OpenNMT/
#  assignment1.sh                               OpenNMT-py-master/
#  BCSEIII/                                     Resume.gdoc
#  BCSEIII1.zip                                 Shankha_BCSEII_78/
# 'Classifieds - Invitations.pptx'              SRN.pdf
# 'Colab Notebooks'/                           'SRN - Shankha raj Nayek.pdf'
#  CSessional_2016.pdf                         'Systems programming'/
#  diffeq.c                                    "test'.ipynb"
#  EN-BN_Word-level.ipynb                       Untitled0.ipynb
#  jordan.c                                     Untitled1.ipynb
# 'Mathematics III 2015.pdf'                   'Who we are.pdf'

# %%
cd OpenNMT
# Out:
# /content/gdrive/My Drive/OpenNMT

# %%
cd tools
# Out:
# /content/gdrive/My Drive/OpenNMT/tools

# %%
cd ..
# Out:
# /content/gdrive/My Drive/OpenNMT

# %%
# !pip install luarocks
# Out:
# ...
#   Could not find a version that satisfies the requirement luarocks (from versions: )
# No matching distribution found for luarocks

# %%
# !import torch
# Out:
# /bin/bash: import: command not found

# %%
# !pip install torch

# %%
# !pip install lua
# Out:
# ...
#   Could not find a version that satisfies the requirement lua (from versions: )
# No matching distribution found for lua

# %%
cd tools
# Out:
# /content/gdrive/My Drive/OpenNMT/tools

# %%
ls
# Out:
# apply_embeddings.lua    learn_bpe.lua                score.lua
# average_models.lua      README.md                    scripts/
# build_vocab.lua         release_model.lua            tokenize.lua
# detokenize.lua          rest_multi_models.lua        translation_server.lua
# embeddings.lua          restserver/                  Ubuntu.en
# extract_embeddings.lua  rest_translation_server.lua  utils/

# %%
# !th tokenize.lua OPTIONS < Ubuntu.en > ubuntu.tok.en
# Out:
# /bin/bash: th: command not found

# %%
# !pip install th
# Out:
# ...
#   Could not find a version that satisfies the requirement th (from versions: )
# No matching distribution found for th

# %%
# !pip install torch-trepl
# Out:
# ...
#   Could not find a version that satisfies the requirement torch-trepl (from versions: )
# No matching distribution found for torch-trepl

# %%
cd ..
# Out:
# /content/gdrive/My Drive/OpenNMT

# %%
cd ..
# Out:
# /content/gdrive/My Drive

# %%
ls
# Out:
# '1)Gujarati-English Translation task:.gdoc'   OpenNMT/
#  assignment1.sh                               OpenNMT-py-master/
#  BCSEIII/                                     Resume.gdoc
#  BCSEIII1.zip                                 Shankha_BCSEII_78/
# 'Classifieds - Invitations.pptx'              SRN.pdf
# 'Colab Notebooks'/                           'SRN - Shankha raj Nayek.pdf'
#  CSessional_2016.pdf                         'Systems programming'/
#  diffeq.c                                    "test'.ipynb"
#  EN-BN_Word-level.ipynb                       Untitled0.ipynb
#  jordan.c                                     Untitled1.ipynb
# 'Mathematics III 2015.pdf'                   'Who we are.pdf'

# %%
cd OpenNMT-py-master/
# Out:
# /content/gdrive/My Drive/OpenNMT-py-master

# %%
ls
# Out:
# available_models/         github_deploy_key_opennmt_opennmt_py.enc
# CHANGELOG.md              LICENSE.md
# config/                   onmt/
# CONTRIBUTING.md           preprocess.py
# data/                     README.md
# demo-model_step_10000.pt  requirements.opt.txt
# demo-model_step_15000.pt  requirements.txt
# demo-model_step_5000.pt   server.py
# Dockerfile                setup.py
# docs/                     tools/
# floyd_requirements.txt    train.py
# floyd.yml                 translate.py

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Cloning https://github.com/pytorch/text to /tmp/pip-req-build-srr4fb1j
# ...
#     100% |████████████████████████████████| 51kB 2.5MB/s
# ...
#   Stored in directory: /root/.cache/pip/wheels/aa/9c/ce/7e904dddb8c7595ffbe3409d24455bc5005852850e36011bda
# ...
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hm9pojwt/wheels/73/14/71/ed033fd999ae4933e17df3e91be2014e61c2f312a88a164ff5
# Successfully built configargparse torchtext
# thinc 6.12.1 has requirement wrapt<1.11.0,>=1.10.0, but you'll have wrapt 1.11.1 which is incompatible.
# spacy 2.0.18 has requirement numpy>=1.15.0, but you'll have numpy 1.14.6 which is incompatible.
# pymc3 3.6 has requirement joblib<0.13.0, but you'll have joblib 0.13.2 which is incompatible.
# featuretools 0.4.1 has requirement pandas>=0.23.0, but you'll have pandas 0.22.0 which is incompatible.
# fastai 1.0.46 has requirement numpy>=1.15, but you'll have numpy 1.14.6 which is incompatible.
# ...
#   Found existing installation: tqdm 4.28.1
#     Uninstalling tqdm-4.28.1:
# ...

# %%
# !for l in en; do for f in data/Gnome.$l; do perl tokenizer.perl -no-escape -l $l -q  < $f > $f.tok; done; done
# Out:
# /bin/bash: data/Gnome.en: No such file or directory

# %%
ls
# Out:
# available_models/         github_deploy_key_opennmt_opennmt_py.enc
# CHANGELOG.md              LICENSE.md
# config/                   onmt/
# CONTRIBUTING.md           preprocess.py
# data/                     README.md
# demo-model_step_10000.pt  requirements.opt.txt
# demo-model_step_15000.pt  requirements.txt
# demo-model_step_5000.pt   server.py
# Dockerfile                setup.py
# docs/                     tools/
# floyd_requirements.txt    train.py
# floyd.yml                 translate.py

# %%
cd data
# Out:
# /content/gdrive/My Drive/OpenNMT-py-master/data

# %%
ls
# Out:
# demo.train.0.pt  demo.vocab.pt  dev.gu    test.en  train.en
# demo.valid.0.pt  dev.en         GNOME.en  test.gu  train.gu

# %%
cd ..
# Out:
# /content/gdrive/My Drive/OpenNMT-py-master

# %%
# !for l in en; do for f in data/Ubuntu.nor.$l; do perl tools/tokenizer.perl -no-escape -l $l -q  < $f > $f.tok; done; done
