# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !ls "/content/gdrive/My Drive"
path="/content/gdrive/My Drive"
# Out:
# '1)Gujarati-English Translation task:.gdoc'   OpenNMT-py-master
#  assignment1.sh				      Resume.gdoc
#  BCSEIII				      Shankha_BCSEII_78
#  BCSEIII1.zip				      SRN.pdf
# 'Classifieds - Invitations.pptx'	     'SRN - Shankha raj Nayek.pdf'
# 'Colab Notebooks'			     'Systems programming'
#  CSessional_2016.pdf			     "test'.ipynb"
#  diffeq.c				      Untitled0.ipynb
#  EN-BN_Word-level.ipynb			      Untitled1.ipynb
#  jordan.c				     'Who we are.pdf'
# 'Mathematics III 2015.pdf'

# %%
cd $path
# Out:
# /content/gdrive/My Drive

# %%
ls
# Out:
# '1)Gujarati-English Translation task:.gdoc'   OpenNMT-py-master/
#  assignment1.sh                               Resume.gdoc
#  BCSEIII/                                     Shankha_BCSEII_78/
#  BCSEIII1.zip                                 SRN.pdf
# 'Classifieds - Invitations.pptx'             'SRN - Shankha raj Nayek.pdf'
# 'Colab Notebooks'/                           'Systems programming'/
#  CSessional_2016.pdf                         "test'.ipynb"
#  diffeq.c                                     Untitled0.ipynb
#  EN-BN_Word-level.ipynb                       Untitled1.ipynb
#  jordan.c                                    'Who we are.pdf'
# 'Mathematics III 2015.pdf'

# %%
cd OpenNMT-py-master
# Out:
# /content/gdrive/My Drive/OpenNMT-py-master

# %%
ls
# Out:
# available_models/                         onmt/
# CHANGELOG.md                              pred.txt
# config/                                   preprocess.py
# CONTRIBUTING.md                           README.md
# data/                                     requirements.opt.txt
# demo-model_step_90000.pt                  requirements.txt
# Dockerfile                                server.py
# docs/                                     setup.py
# floyd_requirements.txt                    tools/
# floyd.yml                                 train.py
# github_deploy_key_opennmt_opennmt_py.enc  translate.py
# LICENSE.md

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Cloning https://github.com/pytorch/text to /tmp/pip-req-build-nahunxtj
# ...
#     100% |████████████████████████████████| 51kB 2.0MB/s
# ...
#   Stored in directory: /root/.cache/pip/wheels/aa/9c/ce/7e904dddb8c7595ffbe3409d24455bc5005852850e36011bda
# ...
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3h3er3h2/wheels/73/14/71/ed033fd999ae4933e17df3e91be2014e61c2f312a88a164ff5
# Successfully built configargparse torchtext
# thinc 6.12.1 has requirement wrapt<1.11.0,>=1.10.0, but you'll have wrapt 1.11.1 which is incompatible.
# spacy 2.0.18 has requirement numpy>=1.15.0, but you'll have numpy 1.14.6 which is incompatible.
# pymc3 3.6 has requirement joblib<0.13.0, but you'll have joblib 0.13.2 which is incompatible.
# featuretools 0.4.1 has requirement pandas>=0.23.0, but you'll have pandas 0.22.0 which is incompatible.
# ...
#   Found existing installation: tqdm 4.28.1
#     Uninstalling tqdm-4.28.1:
#       Successfully uninstalled tqdm-4.28.1
#   Found existing installation: torchtext 0.3.1
# ...

# %%
# !python preprocess.py -train_src data/train.bpe.en -train_tgt data/train.romanised.bpe.hi -valid_src data/dev.bpe.en -valid_tgt data/dev.romanised.bpe.hi -save_data data/demo
# Out:
# [2019-02-25 12:14:38,643 INFO] Extracting features...
# [2019-02-25 12:14:39,481 INFO]  * number of source features: 0.
# [2019-02-25 12:14:39,481 INFO]  * number of target features: 0.
# [2019-02-25 12:14:39,481 INFO] Building `Fields` object...
# [2019-02-25 12:14:39,481 INFO] Building & saving training data...
# [2019-02-25 12:14:39,481 INFO] Reading source and target files: data/train.bpe.en data/train.romanised.bpe.hi.
# [2019-02-25 12:14:40,933 INFO] Building shard 0.
# [2019-02-25 12:14:42,692 INFO]  * saving 0th train data shard to data/demo.train.0.pt.
# [2019-02-25 12:14:45,011 INFO] Building & saving validation data...
# [2019-02-25 12:14:45,012 INFO] Reading source and target files: data/dev.bpe.en data/dev.romanised.bpe.hi.
# [2019-02-25 12:14:45,743 INFO] Building shard 0.
# [2019-02-25 12:14:45,752 INFO]  * saving 0th valid data shard to data/demo.valid.0.pt.
# [2019-02-25 12:14:45,802 INFO] Building & saving vocabulary...
# ...

# %%
# !python train.py -data data/demo -save_model demo-model -gpu_ranks 0
# Out:
# [2019-02-25 15:38:20,975 INFO]  * src vocab size = 10132
# [2019-02-25 15:38:20,976 INFO]  * tgt vocab size = 10149
# [2019-02-25 15:38:20,976 INFO] Building model...
# [2019-02-25 15:38:24,077 INFO] NMTModel(
#   (encoder): RNNEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(10132, 500, padding_idx=1)
#         )
#       )
#     )
#     (rnn): LSTM(500, 500, num_layers=2, dropout=0.3)
#   )
#   (decoder): InputFeedRNNDecoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(10149, 500, padding_idx=1)
#         )
#       )
#     )
#     (dropout): Dropout(p=0.3)
#     (rnn): StackedLSTM(
#       (dropout): Dropout(p=0.3)
#       (layers): ModuleList(
#         (0): LSTMCell(1000, 500)
#         (1): LSTMCell(500, 500)
#       )
#     )
#     (attn): GlobalAttention(
# ...

# %%
# !python translate.py -model demo-model_step_20000.pt -src data/test.bpe.en -output pred.txt -replace_unk -verbose
# Out:
# [2019-02-25 15:51:58,997 INFO] Translating shard 0.
#
# SENT 1: ['P@@', 'rin@@', 'ce', 'A@@', 'sh@@', 'it@@', 'a@@', 'ka@@', ',', 'are', 'you', 'st@@', 'ee@@', 'led', 'to', 'ga@@', 'ze', 'up@@', 'on', 'your', 'f@@', 'at@@', 'e?']
# PRED 1: P@@ ur@@ y@@ , aap apanee haddiyoom par khel kar rahe haim
# PRED SCORE: -20.6827
#
# SENT 2: ['Stor@@', 'm', 'will', 'be', 'the', 'closest', 'man', 'to', 'him.']
# PRED 2: thoophaan aadamee usake lie aadamee hoo jaaegaa
# PRED SCORE: -5.7081
#
# SENT 3: ['Well,', 'I@@', 'l@@', 'se,', 'now', 'you', 'have', 'to', 'eat', 'something,', 'too.']
# PRED 3: theek hai, ab, aap bhee kuchh khaanaa khaane ke lie hai
# PRED SCORE: -7.2271
#
# SENT 4: ["Don't", 'call', 'me', 'again,', 'you', 'jack@@', 'as@@', 's.']
# PRED 4: phir mujhhe phoon math karoo, laanath hai
# PRED SCORE: -4.9870
#
# SENT 5: ['Your', 's@@', 'mi@@', 'le', 'is', 'sa@@', 'ying', 'it', 'l@@', 'ou@@', 'd@@', 'ly,', 'my', 'dear@@', '...']
# PRED 5: apanee slet yah kar rahaa hai, meree betee
# ...

# %%
# !perl tools/multi-bleu.perl data/test.romanised.hi < pred.txt
# Out:
# BLEU = 9.81, 39.5/17.0/8.1/4.0 (BP=0.807, ratio=0.823, hyp_len=11829, ref_len=14365)
